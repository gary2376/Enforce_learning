# %%
import pandas as pd
import os

# 原始檔案資料夾與輸出路徑
input_dir = '../stock_all'
output_dir = '../converted_stock'
os.makedirs(output_dir, exist_ok=True)

for filename in os.listdir(input_dir):
    if not filename.endswith('.csv'):
        continue

    fpath = os.path.join(input_dir, filename)
    print(f"處理檔案: {filename}")

    # 讀檔並指定欄位名稱（手動設定正確欄位）
    df = pd.read_csv(fpath, skiprows=2)
    df.columns = ['date', 'close', 'high', 'low', 'open', 'volume']

    # 加入 ticker（從檔名取代）
    ticker = filename.replace('.csv', '')
    df['tic'] = ticker

    # 格式化日期欄
    df['date'] = pd.to_datetime(df['date']).dt.strftime('%Y-%m-%d')

    # 選擇 FinRL 所需欄位順序
    df = df[['date', 'open', 'high', 'low', 'close', 'volume', 'tic']]

    # 輸出轉換後的檔案
    out_path = os.path.join(output_dir, f"converted_{filename}")
    df.to_csv(out_path, index=False)
    print(f"✅ 已轉換並儲存至：{out_path}")
# Out:
# 處理檔案: 1101.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_1101.TW.csv
# 處理檔案: 2305.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_2305.TW.csv
# 處理檔案: 2454.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_2454.TW.csv
# 處理檔案: 1326.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_1326.TW.csv
# 處理檔案: 2317.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_2317.TW.csv
# 處理檔案: 3045.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_3045.TW.csv
# 處理檔案: 2885.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_2885.TW.csv
# 處理檔案: 0050.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_0050.TW.csv
# 處理檔案: 2303.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_2303.TW.csv
# 處理檔案: 3006.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_3006.TW.csv
# 處理檔案: 2881.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_2881.TW.csv
# 處理檔案: 3673.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_3673.TW.csv
# 處理檔案: 2356.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_2356.TW.csv
# 處理檔案: 2606.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_2606.TW.csv
# 處理檔案: 3231.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_3231.TW.csv
# 處理檔案: 2618.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_2618.TW.csv
# 處理檔案: 9911.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_9911.TW.csv
# 處理檔案: 2002.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_2002.TW.csv
# 處理檔案: 2883.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_2883.TW.csv
# 處理檔案: 3008.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_3008.TW.csv
# 處理檔案: 1402.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_1402.TW.csv
# 處理檔案: 2891.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_2891.TW.csv
# 處理檔案: 2301.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_2301.TW.csv
# 處理檔案: 3481.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_3481.TW.csv
# 處理檔案: 2354.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_2354.TW.csv
# 處理檔案: 2379.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_2379.TW.csv
# 處理檔案: 2308.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_2308.TW.csv
# 處理檔案: 2886.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_2886.TW.csv
# 處理檔案: 2412.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_2412.TW.csv
# 處理檔案: 1303.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_1303.TW.csv
# 處理檔案: 2603.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_2603.TW.csv
# 處理檔案: 1722.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_1722.TW.csv
# 處理檔案: 1102.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_1102.TW.csv
# 處理檔案: 2884.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_2884.TW.csv
# 處理檔案: 2377.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_2377.TW.csv
# 處理檔案: 2330.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_2330.TW.csv
# 處理檔案: 1301.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_1301.TW.csv
# 處理檔案: 2609.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_2609.TW.csv
# 處理檔案: 3711.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_3711.TW.csv
# 處理檔案: 2357.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_2357.TW.csv
# 處理檔案: 2892.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_2892.TW.csv
# 處理檔案: 2880.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_2880.TW.csv
# 處理檔案: 2408.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_2408.TW.csv
# 處理檔案: 2347.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_2347.TW.csv
# 處理檔案: 2882.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_2882.TW.csv
# 處理檔案: 3005.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_3005.TW.csv
# 處理檔案: 2890.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_2890.TW.csv
# 處理檔案: 9910.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_9910.TW.csv
# 處理檔案: 2615.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_2615.TW.csv
# 處理檔案: 2382.TW.csv
# ✅ 已轉換並儲存至：../converted_stock/converted_2382.TW.csv
